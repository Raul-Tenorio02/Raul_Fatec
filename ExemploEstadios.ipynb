# %% [markdown]
# <a href="https://colab.research.google.com/github/Raul-Tenorio02/Raul_restaurantsMongoDB/blob/main/ExemploEstadios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
#   File "<ipython-input-8-e3e0d839c379>", line 7
#     client = mongodb+srv://raulamaral2005:Mongosenhamonga@clusterestadios.yxnlh.mongodb.net/?retryWrites=true&w=majority&appName=ClusterEstadios
#                         ^
# SyntaxError: invalid syntax

# %%
dataset= "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv

# %%
estadios_df = pd.read_csv(dataset)

# %%
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
dicionario = estadios_df.to_dict('records')

# %%
cliente = MongoClient("mongodb+srv://raulamaral2005:Mongosenhamonga@clusterestadios.yxnlh.mongodb.net/?retryWrites=true&w=majority&appName=ClusterEstadios")

# %%
db = cliente.get_database('Futebol')

# %%
db.Estadios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('671ad9a13388ba198e1099a5'), ObjectId('671ad9a13388ba198e1099a6'), ObjectId('671ad9a13388ba198e1099a7'), ObjectId('671ad9a13388ba198e1099a8'), ObjectId('671ad9a13388ba198e1099a9'), ObjectId('671ad9a13388ba198e1099aa'), ObjectId('671ad9a13388ba198e1099ab'), ObjectId('671ad9a13388ba198e1099ac'), ObjectId('671ad9a13388ba198e1099ad'), ObjectId('671ad9a13388ba198e1099ae'), ObjectId('671ad9a13388ba198e1099af'), ObjectId('671ad9a13388ba198e1099b0'), ObjectId('671ad9a13388ba198e1099b1'), ObjectId('671ad9a13388ba198e1099b2'), ObjectId('671ad9a13388ba198e1099b3'), ObjectId('671ad9a13388ba198e1099b4'), ObjectId('671ad9a13388ba198e1099b5'), ObjectId('671ad9a13388ba198e1099b6'), ObjectId('671ad9a13388ba198e1099b7'), ObjectId('671ad9a13388ba198e1099b8')], acknowledged=True)

# %%
estadios = db.Estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['clusterestadios-shard-00-02.yxnlh.mongodb.net:27017', 'clusterestadios-shard-00-01.yxnlh.mongodb.net:27017', 'clusterestadios-shard-00-00.yxnlh.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='ClusterEstadios', authsource='admin', replicaset='atlas-vlg4m7-shard-0', tls=True), 'Futebol'), 'Estadios')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('671ad9a13388ba198e1099a5'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('671ad9a13388ba198e1099a6'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('671ad9a13388ba198e1099a7'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('671ad9a13388ba198e1099a8'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('671ad9a13388ba198e1099a9'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('671ad9a13388ba198e1099aa'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('671ad9a13388ba198e1099ab'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('671ad9a13388ba198e1099ac'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('671ad9a13388ba198e1099ad'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('671ad9a13388ba198e1099ae'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('671ad9a13388ba198e1099af'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('671ad9a13388ba198e1099b0'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('671ad9a13388ba198e1099b1'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('671ad9a13388ba198e1099b2'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('671ad9a13388ba198e1099b3'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('671ad9a13388ba198e1099b4'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('671ad9a13388ba198e1099b5'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('671ad9a13388ba198e1099b6'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('671ad9a13388ba198e1099b7'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('671ad9a13388ba198e1099b8'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
center_lat = -14.24007
center_lon = -53.18050

# %%
consulta = list(estadios.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id           671ad9a13388ba198e1099a5
# nome                          Maracanã
# capacidade                       78838
# latitude                     -22.90981
# longitude                    -43.23391
# Name: 0, dtype: object

# %%
locationmap = folium.Map(location=[center_lat, center_lon], zoom_start=5, width=800,height = 600)

# %%
qtde = len(df_convertido)
qtde
# Out:
# 20

# %%
for i in range(qtde):
    lng = float(df_convertido.iloc[i]['longitude'])
    lat = float(df_convertido.iloc[i]['latitude'])
    description = 'Estádio: ' + str(df_convertido.iloc[i]['nome'])+'<br> Capacidade: ' +str(df_convertido.iloc[i]['capacidade'])
    folium.Marker([lat, lng],
                  popup = description,
                  icon = folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59de1301f6f62040456f120166d918a0 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59de1301f6f62040456f120166d918a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59de1301f6f62040456f120166d918a0 = L.map(
#                 &quot;map_59de1301f6f62040456f120166d918a0&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5aacfdc6443ab17e4a5340875356f7a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b5aacfdc6443ab17e4a5340875356f7a.addTo(map_59de1301f6f62040456f120166d918a0);
#
#
#             var marker_e031d1b69ff5daee7c0da5c200b6d288 = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_59de1301f6f62040456f120166d918a0);
#
#
#             var icon_ac04b5884fdf3ee66f5805dddb0d35c0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e031d1b69ff5daee7c0da5c200b6d288.setIcon(icon_ac04b5884fdf3ee66f5805dddb0d35c0);
#
#
#         var popup_a69e397b7c8ca113d65d4b6801afffba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63fd1e84c3de039d3bec6fc1c0407ab5 = $(`&lt;div id=&quot;html_63fd1e84c3de039d3bec6fc1c0407ab5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Maracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_a69e397b7c8ca113d65d4b6801afffba.setContent(html_63fd1e84c3de039d3bec6fc1c0407ab5);
#
#
#
#         marker_e031d1b69ff5daee7c0da5c200b6d288.bindPopup(popup_a69e397b7c8ca113d65d4b6801afffba)
#         ;
#
#
#
#
#             var marker_c67421e81440448545a494b8c64e7190 = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_59de1301f6f62040456f120166d918a0);
#
#
#             var icon_e5bcca0acfb475df30d6aaa793ed5ea6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c67421e81440448545a494b8c64e7190.setIcon(icon_e5bcca0acfb475df30d6aaa793ed5ea6);
#
#
#         var popup_0252f345c94428de849b0e2589556237 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b1ecd00fbc8fb3e80655a77af2325e0 = $(`&lt;div id=&quot;html_8b1ecd00fbc8fb3e80655a77af2325e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Mané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_0252f345c94428de849b0e2589556237.setContent(html_8b1ecd00fbc8fb3e80655a77af2325e0);
#
#
#
#         marker_c67421e81440448545a494b8c64e7190.bindPopup(popup_0252f345c94428de849b0e2589556237)
#         ;
#
#
#
#
#             var marker_fa5582c33912d511e417194556b5ca4c = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_59de1301f6f62040456f120166d918a0);
#
#
#             var icon_41000fe1c2198e1359f2b53e71909dbc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fa5582c33912d511e417194556b5ca4c.setIcon(icon_41000fe1c2198e1359f2b53e71909dbc);
#
#
#         var popup_400566cd1ab8047c27772ddc22c8c48a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16f03a1047ffac0792b67e4d922066ca = $(`&lt;div id=&quot;html_16f03a1047ffac0792b67e4d922066ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Morumbi&lt;br&gt; Capacidade: 66795&lt;/div&gt;`)[0];
#                 popup_400566cd1ab8047c27772ddc22c8c48a.setContent(html_16f03a1047ffac0792b67e4d922066ca);
#
#
#
#         marker_fa5582c33912d511e417194556b5ca4c.bindPopup(popup_400566cd1ab8047c27772ddc22c8c48a)
#         ;
#
#
#
#
#             var marker_e54ce0ffa1bf0692382d6e491dea6dfb = L.marker(
#                 [-3.80674, -38.52168],
#                 {}
#             ).addTo(map_59de1301f6f62040456f120166d918a0);
#
#
#             var icon_26628cff54fc117ee05893848abf8511 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate
